# %% [markdown]
# ![Titanic-iceberg-British-15-1912.webp](attachment:Titanic-iceberg-British-15-1912.webp)

# %%
import pandas as pd
import numpy as np
import warnings
import matplotlib.pyplot as plt
import seaborn as sns
warnings.filterwarnings('ignore')

# %%
data= pd.read_csv('./titanic.csv')
data.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
data.drop(columns=["Cabin","PassengerId","Name"],inplace=True)
data.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch            Ticket     Fare  \
# 0         0       3    male  22.0      1      0         A/5 21171   7.2500
# 1         1       1  female  38.0      1      0          PC 17599  71.2833
# 2         1       3  female  26.0      0      0  STON/O2. 3101282   7.9250
# 3         1       1  female  35.0      1      0            113803  53.1000
# 4         0       3    male  35.0      0      0            373450   8.0500
#
#   Embarked
# 0        S
# 1        C
# 2        S
# 3        S
# 4        S

# %%
data.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch            Ticket     Fare  \
# 0         0       3    male  22.0      1      0         A/5 21171   7.2500
# 1         1       1  female  38.0      1      0          PC 17599  71.2833
# 2         1       3  female  26.0      0      0  STON/O2. 3101282   7.9250
# 3         1       1  female  35.0      1      0            113803  53.1000
# 4         0       3    male  35.0      0      0            373450   8.0500
#
#   Embarked
# 0        S
# 1        C
# 2        S
# 3        S
# 4        S

# %%
data.tail()
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch      Ticket   Fare Embarked
# 886         0       2    male  27.0      0      0      211536  13.00        S
# 887         1       1  female  19.0      0      0      112053  30.00        S
# 888         0       3  female   NaN      1      2  W./C. 6607  23.45        S
# 889         1       1    male  26.0      0      0      111369  30.00        C
# 890         0       3    male  32.0      0      0      370376   7.75        Q

# %%
data.sample(12)
# Out:
#      Survived  Pclass     Sex    Age  SibSp  Parch         Ticket      Fare  \
# 855         1       3  female  18.00      0      1         392091    9.3500
# 376         1       3  female  22.00      0      0         C 7077    7.2500
# 547         1       2    male    NaN      0      0  SC/PARIS 2146   13.8625
# 464         0       3    male    NaN      0      0       A/S 2816    8.0500
# 825         0       3    male    NaN      0      0         368323    6.9500
# 821         1       3    male  27.00      0      0         315098    8.6625
# 305         1       1    male   0.92      1      2         113781  151.5500
# 412         1       1  female  33.00      1      0          19928   90.0000
# 237         1       2  female   8.00      0      2     C.A. 31921   26.2500
# 186         1       3  female    NaN      1      0         370365   15.5000
# 419         0       3  female  10.00      0      2         345773   24.1500
# ...

# %%
data.dropna()
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch            Ticket     Fare  \
# 0           0       3    male  22.0      1      0         A/5 21171   7.2500
# 1           1       1  female  38.0      1      0          PC 17599  71.2833
# 2           1       3  female  26.0      0      0  STON/O2. 3101282   7.9250
# 3           1       1  female  35.0      1      0            113803  53.1000
# 4           0       3    male  35.0      0      0            373450   8.0500
# ..        ...     ...     ...   ...    ...    ...               ...      ...
# 885         0       3  female  39.0      0      5            382652  29.1250
# 886         0       2    male  27.0      0      0            211536  13.0000
# 887         1       1  female  19.0      0      0            112053  30.0000
# 889         1       1    male  26.0      0      0            111369  30.0000
# 890         0       3    male  32.0      0      0            370376   7.7500
#
#     Embarked
# 0          S
# 1          C
# ...

# %%
data.isnull().mean()**100
# Out:
# Survived     0.000000e+00
# Pclass       0.000000e+00
# Sex          0.000000e+00
# Age          6.449948e-71
# SibSp        0.000000e+00
# Parch        0.000000e+00
# Ticket       0.000000e+00
# Fare         0.000000e+00
# Embarked    1.303855e-265
# dtype: float64

# %%
data.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Embarked      2
# dtype: int64

# %%
data.size
# Out:
# 8019

# %%
data.columns
# Out:
# Index(['Survived', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare',
#        'Embarked'],
#       dtype='object')

# %%
data.Pclass.dtype
# Out:
# dtype('int64')

# %%
data.duplicated().sum()
# Out:
# 15

# %%
data.dropna(inplace=True)
data.drop_duplicates(inplace=True)

# %%
data[data['Fare']>30]
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch    Ticket      Fare Embarked
# 1           1       1  female  38.0      1      0  PC 17599   71.2833        C
# 3           1       1  female  35.0      1      0    113803   53.1000        S
# 6           0       1    male  54.0      0      0     17463   51.8625        S
# 9           1       2  female  14.0      1      0    237736   30.0708        C
# 13          0       3    male  39.0      1      5    347082   31.2750        S
# ..        ...     ...     ...   ...    ...    ...       ...       ...      ...
# 853         1       1  female  16.0      0      1  PC 17592   39.4000        S
# 856         1       1  female  45.0      1      1     36928  164.8667        S
# 867         0       1    male  31.0      0      0  PC 17590   50.4958        S
# 871         1       1  female  47.0      1      1     11751   52.5542        S
# 879         1       1  female  56.0      0      1     11767   83.1583        C
#
# [199 rows x 9 columns]

# %% [markdown]
# ## Histogram

# %% [markdown]
# #### Number of female passengers survived.

# %%
female =data.query("Sex=='female'& Age>30 & Survived ==1")

# %%
sns.histplot(data=data,x='Age')
plt.show()

# %%
sns.histplot(data=data,x='Pclass')
plt.show()

# %% [markdown]
# ## KDE Plot

# %%
sns.kdeplot(data=data,x='Age')
plt.show()

# %%
data.Survived.value_counts().index
# Out:
# Int64Index([0, 1], dtype='int64')

# %% [markdown]
# ## sub plot in matplotlib

# %%
plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
sns.boxplot(data=data,y='Age',color='green')
plt.subplot(2,2,2)
sns.boxplot(data=data,y='Pclass',color='yellow')
plt.subplot(2,2,3)
sns.boxplot(data=data,y='Fare',color='red')
plt.subplot(2,2,4)
sns.boxplot(data=data,y='Parch',color='orange')
plt.show()

# %% [markdown]
# ## Box Plot

# %%
sns.boxplot(data=data,x='Age')
plt.show()

# %%
sns.boxplot(data=data,x='Fare')
plt.show()

# %%
female =data.query("Sex=='female'& Age>30 & Survived ==1")
female
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch    Ticket      Fare Embarked
# 1           1       1  female  38.0      1      0  PC 17599   71.2833        C
# 3           1       1  female  35.0      1      0    113803   53.1000        S
# 11          1       1  female  58.0      0      0    113783   26.5500        S
# 15          1       2  female  55.0      0      0    248706   16.0000        S
# 25          1       3  female  38.0      1      5    347077   31.3875        S
# ..        ...     ...     ...   ...    ...    ...       ...       ...      ...
# 856         1       1  female  45.0      1      1     36928  164.8667        S
# 862         1       1  female  48.0      0      0     17466   25.9292        S
# 865         1       2  female  42.0      0      0    236852   13.0000        S
# 871         1       1  female  47.0      1      1     11751   52.5542        S
# 879         1       1  female  56.0      0      1     11767   83.1583        C
#
# [81 rows x 9 columns]

# %% [markdown]
# ## Hex Plot

# %%
data.plot.hexbin('Fare','Age',gridsize=16,cmap='gist_stern');

# %%
male_survived=data.groupby(['Pclass'])['Survived'].sum()
male_survived
# Out:
# Pclass
# 1    119
# 2     83
# 3     83
# Name: Survived, dtype: int64

# %%
female_survived=data.groupby(['Fare']).sum()
female_survived
# Out:
#           Survived  Pclass    Age  SibSp  Parch
# Fare
# 0.0000           1      15  246.0      0      0
# 4.0125           0       3   20.0      0      0
# 5.0000           0       1   33.0      0      0
# 6.2375           0       3   61.0      0      0
# 6.4375           0       3   34.5      0      0
# ...            ...     ...    ...    ...    ...
# 227.5250         3       3   98.0      1      0
# 247.5208         1       2   74.0      0      2
# 262.3750         2       2   39.0      4      4
# 263.0000         2       4  130.0     10     10
# 512.3292         3       3  106.0      0      1
#
# [219 rows x 5 columns]

# %% [markdown]
# ## Pie Plot

# %%
male_survived.plot.pie(autopct='%1.5f%%',legend=True);

# %%
palette_color = sns.color_palette('dark')

# %%
plt.pie(data=data, x=data.Survived.value_counts(),explode = [0.1, 0], colors=palette_color,labels=['male','female'],autopct='%0.2f%%');

# %% [markdown]
# ## Cat Plot

# %%
sns.catplot(data = data, x = 'Survived', y= 'Age')
plt.show()

# %%
data.nlargest(1,'Fare')
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch    Ticket      Fare Embarked
# 258         1       1  female  35.0      0      0  PC 17755  512.3292        C

# %%
data.nsmallest(1,'Age')
# Out:
#      Survived  Pclass   Sex   Age  SibSp  Parch Ticket    Fare Embarked
# 803         1       3  male  0.42      0      1   2625  8.5167        C

# %%
Gender_count= pd.crosstab(data.Sex,data.Fare)

# %%
Gender_count
# Out:
# Fare    0.0000    4.0125    5.0000    6.2375    6.4375    6.4500    6.4958    \
# Sex
# female         0         0         0         0         0         0         0
# male           7         1         1         1         1         1         2
#
# Fare    6.7500    6.9750    7.0458    ...  151.5500  153.4625  164.8667  \
# Sex                                   ...
# female         1         0         0  ...         3         2         2
# male           1         2         1  ...         1         1         0
#
# Fare    211.3375  211.5000  227.5250  247.5208  262.3750  263.0000  512.3292
# Sex
# female         3         0         3         1         2         2         1
# male           0         1         0         1         0         2         2
#
# [2 rows x 219 columns]

# %% [markdown]
# ## Count Plot

# %%
plt.figure(figsize=(16,9))
plt.xticks(rotation = 90)
sns.countplot(data=data,x='Survived',hue='Sex')
plt.show()

# %%
sns.countplot(x='Survived', data=data);

# %% [markdown]
# ## Horizontal bar chart

# %%
plt.figure(figsize=(6,6))
plt.xticks(rotation=75)
sns.barplot(data=data,x='Survived',y='Age',hue='Sex')
plt.show()

# %%
plt.figure(figsize=(16,9))
plt.xticks(rotation = 90)
sns.countplot(data=data,x='SibSp')
plt.show()

# %%
plt.figure(figsize=(16,5))
plt.xticks(rotation = 90)
sns.countplot(data=data,x='Parch')
plt.show()

# %% [markdown]
# ## Line Plot

# %%
plt.figure(figsize=(10,6))
plt.xlabel('Age')

plt.ylabel('Survived')
sns.lineplot(data=data,x='Age', y='Fare',hue='Sex')
plt.show()

# %% [markdown]
# ## Boxen Plot

# %%
sns.boxenplot(data=data,y='Age',color='green')
plt.show()

# %% [markdown]
# ## violin plot

# %%
sns.violinplot(data=data,y='Fare',color='red')
plt.show()

# %% [markdown]
# ## joint plot

# %%
sns.jointplot(data=data,x='Age',y='Fare',color='blue')
plt.show()

# %%
sns.jointplot(data=data,x='Age',y='Fare',kind='hex',color='violet')
plt.show()

# %% [markdown]
# ## Swarm plot

# %%
sns.swarmplot(data=data,x='Sex',y='Age',color='green')
plt.show()

# %% [markdown]
# ## Scatter Plot

# %%
sns.scatterplot(data=data,x='Age',y='Fare',hue="Sex")
plt.show()

# %%
sns.scatterplot(data=data,x='Age',y='Fare',hue="Sex")
plt.show()

# %% [markdown]
# ## Reg Plot

# %%
sns.regplot(data=data,x='Age',y='Fare',color='indigo')
plt.show()

# %% [markdown]
# ## Rel Plot

# %%
sns.relplot(data=data,x='Age',y='Fare',hue='Sex')
plt.show()
